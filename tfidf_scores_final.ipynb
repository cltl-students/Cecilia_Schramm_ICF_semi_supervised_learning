# %%
import pandas as pd
import pickle
import numpy as np
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %%
import nl_core_news_sm

# %%
#pip install https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.5.0/nl_core_news_sm-3.5.0-py3-none-any.whl

# %%
#pip install https://github.com/explosion/spacy-models/releases/download/nl_core_news_sm-3.5.0/nl_core_news_sm-3.5.0.tar.gz

# %% [raw]
# corpus = [list of all sentences in all annotated data]
#     ellemijn - done
#     jenia - done
#     sharona - done
# dict_all = {stm:senctence ... mbw:sentence etc.}
#
# tf_idf = tfidf for all corpus
# dict_stm = {}
# dict_mbw = {}
#
# for key, value in dict_all.items():
#     if key == "stm":
#         words = value.split()
#         for word in words:
#             dict_stm[word] = tf_idf[word][word_score]
#     if key == "mbw":
#         etc.
#
# sort all dicts
#
# look at all words with scores above 0.7 or 0.8

# %%
corpus = []

# %%
dict_all = {"stm": [], "mbw": [], "ins": [], "fac": [], "etn": [], "enr": [], "ber": [], "att": [], "adm": []}

# %% [markdown]
# ## Ellemijn's data

# %% [raw]
# # training data
# df_ellemijn_train_stm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_STM_sents/train.pkl')
# df_ellemijn_train_mbw = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_MBW_sents/train.pkl')
# df_ellemijn_train_ins = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_INS_sents/train.pkl')
# df_ellemijn_train_fac = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_FAC_sents/train.pkl')
# df_ellemijn_train_enr = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ENR_sents/train.pkl')
# df_ellemijn_train_ber = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_BER_sents/train.pkl')
# df_ellemijn_train_att = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ATT_sents/train.pkl')
# df_ellemijn_train_adm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ADM_sents/train.pkl')

# %% [raw]
# # test data
# df_ellemijn_test_stm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_STM_sents/test.pkl')
# df_ellemijn_test_mbw = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_MBW_sents/test.pkl')
# df_ellemijn_test_ins = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_INS_sents/test.pkl')
# df_ellemijn_test_fac = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_FAC_sents/test.pkl')
# df_ellemijn_test_enr = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ENR_sents/test.pkl')
# df_ellemijn_test_ber = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_BER_sents/test.pkl')
# df_ellemijn_test_att = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ATT_sents/test.pkl')
# df_ellemijn_test_adm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ADM_sents/test.pkl')

# %% [raw]
# # dev data
# df_ellemijn_dev_stm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_STM_sents/dev.pkl')
# df_ellemijn_dev_mbw = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_MBW_sents/dev.pkl')
# df_ellemijn_dev_ins = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_INS_sents/dev.pkl')
# df_ellemijn_dev_fac = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_FAC_sents/dev.pkl')
# df_ellemijn_dev_enr = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ENR_sents/dev.pkl')
# df_ellemijn_dev_ber = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_BER_sents/dev.pkl')
# df_ellemijn_dev_att = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ATT_sents/dev.pkl')
# df_ellemijn_dev_adm = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_ADM_sents/dev.pkl')

# %%
# training data

domains = ["stm", "mbw", "ins", "fac", "enr", "ber", "att", "adm"]

ellemijn_train_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_' + i.upper() + '_sents/train.pkl')
    ellemijn_train_data["df_ellemijn_train_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
# test data

domains = ["stm", "mbw", "ins", "fac", "enr", "ber", "att", "adm"]

ellemijn_test_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_' + i.upper() + '_sents/test.pkl')
    ellemijn_test_data["df_ellemijn_test_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
# dev data

domains = ["stm", "mbw", "ins", "fac", "enr", "ber", "att", "adm"]

ellemijn_dev_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/Users/A-PROOF/ellemijn/a-proof-zonmw-main/ANNOTATIONS_INCEPTION/clf_levels_incl_primary_' + i.upper() + '_sents/dev.pkl')
    ellemijn_dev_data["df_ellemijn_dev_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
#ellemijn_STM_train_text = df_ellemijn_train['text'].values.tolist()

# %%
for value in ellemijn_train_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 640

# %%
for value in ellemijn_test_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 704

# %%
for value in ellemijn_dev_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 768

# %% [markdown]
# ## Jenia's data

# %%
# training data

domains = ["stm", "mbw", "ins", "fac", "etn", "enr", "ber", "att", "adm"]

jenia_train_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/A-Proof/data2/a-proof-zonmw/data/expr_sept/clf_levels_' + i.upper() + '_sents/train.pkl')
    jenia_train_data["df_jenia_train_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
# test data

domains = ["stm", "mbw", "ins", "fac", "etn", "enr", "ber", "att", "adm"]

jenia_test_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/A-Proof/data2/a-proof-zonmw/data/expr_sept/clf_levels_' + i.upper() + '_sents/test.pkl')
    jenia_test_data["df_jenia_test_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
# dev data

domains = ["stm", "mbw", "ins", "fac", "etn", "enr", "ber", "att", "adm"]

jenia_dev_data = {}

for i in domains:
    df = pd.read_pickle('/mnt/data/A-Proof/data2/a-proof-zonmw/data/expr_sept/clf_levels_' + i.upper() + '_sents/dev.pkl')
    jenia_dev_data["df_jenia_dev_"+ i] = df
    for sent in df['text'].values.tolist():
        dict_all[i].append(sent)

# %%
for value in jenia_train_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 14340

# %%
for value in jenia_test_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 15592

# %%
for value in jenia_dev_data.values():
    sents = value['text'].values.tolist()
    for sent in sents:
        corpus.append(sent)
        
print(len(corpus))
# Out:
# 16929

# %% [markdown]
# ## Sharona's data

# %%
df_sharona = pd.read_pickle('/mnt/data/Users/A-PROOF/sharona/homedirs/sharona/Documents/a-proof-zonmw-main/data/for_ml/clf_domains/train.pkl')

# %%
for i in range(df_sharona.shape[0]):
    if df_sharona['labels'][i][0] == 1:
        dict_all["adm"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][1] == 1:
        dict_all["att"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][2] == 1:
        dict_all["ber"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][3] == 1:
        dict_all["enr"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][4] == 1:
        dict_all["etn"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][5] == 1:
        dict_all["fac"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][6] == 1:
        dict_all["ins"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][7] == 1:
        dict_all["mbw"].append(df_sharona['text'][i])
    if df_sharona['labels'][i][0] == 1:
        dict_all["stm"].append(df_sharona['text'][i])

# %%
sharona_text = df_sharona['text'].values.tolist()

# %%
for sent in sharona_text:
    corpus.append(sent)
    
print(len(corpus))
# Out:
# 22149

# %% [markdown]
# ## TF-IDF

# %%
counter = 0

for sents in dict_all.values():
    print(len(sents))
    counter += len(sents)
    
print(counter)
# Out:
# 1875
# 1066
# 1582
# 1412
# 3046
# 1482
# 493
# 351
# 6252
# 17559

# %% [raw]
# nlp = spacy.load("nl_core_news_sm")

# %%
test = "Cissy"
listy = ["is", "hot"]

for i in listy:
    test += " " + i
    
print(test)
# Out:
# Cissy is hot

# %%
print(dict_all)
# Out:
# {'stm': ['keer sporten was erg lekker en voelde goed P : copnditie HUR', 'erg emtioneel . vindt', 'het heel erg moeilijk om hiermee om te gaan . vindt', '/ tussenresultaten is weer bgonnen met sporten , gewicht blijft wel constant PERSON nu iets meer , ervaart ook stress .', 'volgende sessie wil graag nog over 2 maanden controle . Vind', 'het prettig om met iemand anders het erover te hebben en het proces te evalueren', 'over gezondheidstoestand vind het moeilijk om toe te geven dat het niet gaat . is', 'het sporten weer heel prettig en vind dat de begeleiding erg professioneel is hier P : kracht', 'van aanpak / uitgevoerde behandeling S : gaat lekker ! gaat meer werken , extra dag en 6 uur per dag P', '/ bezorgd voor de volgende benauwdheidsaanval Regelmatig', '/ beoordeling therapeut moeite met accepteren om rust tussendoor te nemen , dat ze leuke dingen kan doen en niet kan/mag werken .', 'vanwege uw ademhalingsproblemen Af', 'en toe', 'neerslachtig , somber of hopeloos : nee', 'g
# ...

# %%
corpus2 = []

for value in dict_all.values():
    string = ""
    for sent in value:
        string += " " + sent
    corpus2.append(string)

# %%
print(len(corpus2))
# Out:
# 9

# %%
df_idf = pd.DataFrame(corpus2)

# %%
df_idf
# Out:
#                                                    0
# 0   keer sporten was erg lekker en voelde goed P ...
# 1   kg - 105 kg ( 2-3 weken maand 25 kg kwijt / t...
# 2   ( S ) - Blijft intens moe . Kan zich niet ins...
# 3   moe , pijn in lichaam , overprikkeling ( stre...
# 4   Anamnese : Sinds 2 maanden heeft mevrouw het ...
# 5   van aanpak / uitgevoerde behandeling S : merk...
# 6   het moeilijk om niet over haar grenzen te gaa...
# 7   : mentaal en cognitief klachten Huidig functi...
# 8   nog benauwd en erg vermoeid . ( december is m...

# %%
docs = df_idf[0].tolist()

# %%
cv=CountVectorizer(max_df=0.85)
word_count_vector=cv.fit_transform(docs)

# %%
tfidf_transformer=TfidfTransformer(smooth_idf=True, use_idf=True)
tfidf_transformer.fit(word_count_vector)
# Out:
# TfidfTransformer()

# %%
feature_names=cv.get_feature_names_out()

# %%
def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]
    
    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])
        
    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
        
    return results

# %%
domains = ["stm", "mbw", "ins", "fac", "etn", "enr", "ber", "att", "adm"]

# %%
for i in range(len(domains)):
    doc=docs[i]
    tf_idf_vector2 = tfidf_transformer.transform(cv.transform([doc]))
    sorted_items = sort_coo(tf_idf_vector2.tocoo())
    keywords = extract_topn_from_vector(feature_names, sorted_items, 26)
    print("====Domain====")
    print(domains[i])
    print("====Keywords====")
    for k in keywords:
        print(k,keywords[k])
# Out:
# ====Domain====
# stm
# ====Keywords====
# angst 0.37
# stemming 0.337
# angstig 0.288
# bang 0.268
# somber 0.227
# affect 0.221
# emotioneel 0.217
# boos 0.162
# blij 0.152
# depressieve 0.125
# depressie 0.125
# gespannen 0.119
# angsten 0.114
# verdrietig 0.105
# dood 0.104
# doodswens 0.089
# stress 0.087
# modulerend 0.081
# paniek 0.077
# normofoor 0.074
# depressief 0.074
# vrolijk 0.071
# onrustig 0.069
# gedachten 0.065
# gevoelens 0.063
# sombere 0.06
# ====Domain====
# mbw
# ====Keywords====
# afgevallen 0.518
# gewichtsverlies 0.509
# voedingstoestand 0.289
# snaq 0.264
# obv 0.171
# tov 0.156
# ondervoeding 0.152
# gebruikelijk 0.135
# eindscore 0.108
# voeding 0.106
# inflammatie 0.105
# agv 0.1
# afvallen 0.076
# graad 0.072
# anorexie 0.072
# gerelateerde 0.071
# gewichtsverandering 0.062
# bmi 0.062
# acute 0.062
# kilo 0.059
# wb 0.056
# toegenomen 0.05
# nachtzweten 0.05
# gew 0.048
# onbedoeld 0.047
# bewust 0.045
# ====Domain====
# ins
# ====Keywords====
# ...

# %%
dic = {
  "B152": ["angst", "stemming", "angstig", "bang", "somber", "affect", "emotioneel", "boos", "blij",
            "depressieve", "depressie", "gespannen", "angsten", "verdrietig", "dood", "doodswens", 
            "stress", "modulerend", "paniek", "normofoor"],
  "B530": ["afgevallen", "gewichtsverlies", "voedingstoestand", "snaq", "obv", "tov", "ondervoeding",
            "gebruikelijk", "eindscore", "inflammatie", "agv", "afvallen", "anorexie", "gerelateerde",
            "gewichtsverandering", "bmi", "acute", "kilo", "wb", "toegenomen"],
  "B455": ["stoel", "fietsen", "inspanningstolerantie", "wandelen", "gezeten", "fietst", "sport",
            "boodschappen", "km", "huishouden", "wandelt", "buiten", "bedrand", "hond", "fitness",
            "fiets", "gedoucht", "trappen", "mobiliseren", "douchen"],
  "D450": ["fac", "gelopen", "meter", "toilet", "trap", "traplopen", "mob", "afdeling", "supervisie", "rond",
            "veilig","infuuspaal", "personen", "loophulpmiddel", "persoon", "krukken", "transfers", "liep",
            "ondersteuning", "ongestoord"],
  "D550": ["sondevoeding", "voeding", "sv", "dig", "protein", "nutridrink", "sonde", "compact", 
            "ml", "eet", "nutrison", "drinkvoeding", "tpv", "duodenumsonde", "gegeten", "protino",
            "geschatte", "maagsonde", "arla", "eiwitbehoefte"],
  "B1300": ["moeheid", "vermoeiend", "slaperig", "graad", "zwak", "vermoeidheidsklachten", "fit", "suf", 
            "uitgeput", "hur", "vermoeider", "verzwakt", "vermoeide", "wakker", "czs", "slap",
            "balansoefeningen", "watt", "fitter", "ochtend"],
  "D840-D859": ["gewerkt", "uitgevoerde", "aanpak", "psk", "trampoline", "school",
                "dribbelen", "heuvel", "infratechniek", "tik", "balanseren", "stage", "uren",
                "vorm", "volhouden", "beroep", "sociale", "waarde", "werkte", "seconden"],
  "B140": ["aandacht", "trekken", "concentratie", "behouden", "helder", "bewustzijn", "concentratieverlies", 
            "concentreren", "afgeleid", "ogen", "geheugen", "alert", "concentratieproblemen", "reageert",
            "aanspreken", "lezen", "concentratiestoornissen", "adequaat", "vergeetachtigheid", "cognitie"],
  "B440": ["o2", "spo2", "peep", "respiratoire", "beademing", "ademhalingsfrequentie", "fio2", "temperatuur", 
            "zuurstof", "polsfrequentie", "saturatie", "sat", "dyspneu", "lengte", "bloeddruk",
            "temperatuurbron", "resp", "neusbril", "insufficiëntie", "96"]
}

# %%
for key, value in dic.items():
    if len(value) != 20:
        print("no:", key)
