# %%
import pandas as pd
import pickle

# %%
df = pd.read_pickle("/mnt/data/Users/A-PROOF/Cecilia_S/models/fine_tuned/binary/ell_sh_data.pkl")

# %%
df.groupby('pred_best_model').count()
# Out:
#                  pad_sen_id   year  NotitieID  batch  annotator  \
# pred_best_model
# 0                     28136  28136      28136  28136      28136
# 1                      1965   1965       1965   1965       1965
#
#                  background_sent  target_sent  text_raw  labels   text  ...  \
# pred_best_model                                                         ...
# 0                          28136        28136     28136   28136  28136  ...
# 1                           1965         1965      1965    1965   1965  ...
#
#                  secondary_preds  new_secondary_preds  \
# pred_best_model
# 0                          20934                20934
# 1                           1148                 1148
#
#                  icf-domains_combined_prim_sec  \
# pred_best_model
# 0                                        20934
# 1                                         1148
#
#                  /data2/Documents/tmp_ellemijn/icf-domains_incl_primary_10_epochs  \
# ...

# %%
df_1 = df[(df['pred_best_model']== 1)]

# %%
df_1
# Out:
#                   pad_sen_id  year NotitieID                batch annotator  \
# 0109003_0003    0109003_0003  2020   0109003         ergotherapie     edwin
# 0119003_0001    0119003_0001  2020   0119003         ergotherapie     edwin
# 0131001_0005    0131001_0005  2020   0131001        fysiotherapie   meskers
# 0131001_0011    0131001_0011  2020   0131001        fysiotherapie   meskers
# 0131001_0012    0131001_0012  2020   0131001        fysiotherapie   meskers
# ...                      ...   ...       ...                  ...       ...
# 79472723_0010  79472723_0010  2016  79472723        lung_patients     edwin
# 79472723_0012  79472723_0012  2016  79472723        lung_patients     edwin
# 79472723_0017  79472723_0017  2016  79472723        lung_patients     edwin
# 79472723_0021  79472723_0021  2016  79472723        lung_patients     edwin
# 84588639_0001  84588639_0001  2016  84588639  lung_patient_batch3     edwin
#
#                background_sent  target_sent  \
# ...

# %%
df_1.to_pickle("/mnt/data/Users/A-PROOF/Cecilia_S/models/fine_tuned/binary/test_set_pos_ell_sh.pkl")
